# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/drive/MyDrive/Datasets/student.csv")
df
# Out:
#      Math  Reading  Writing
# 0      48       68       63
# 1      62       81       72
# 2      79       80       78
# 3      76       83       79
# 4      59       64       62
# ..    ...      ...      ...
# 995    72       74       70
# 996    73       86       90
# 997    89       87       94
# 998    83       82       78
# 999    66       66       72
#
# [1000 rows x 3 columns]

# %%
df.head(5)
# Out:
#    Math  Reading  Writing
# 0    48       68       63
# 1    62       81       72
# 2    79       80       78
# 3    76       83       79
# 4    59       64       62

# %%
df.tail(5)
# Out:
#      Math  Reading  Writing
# 995    72       74       70
# 996    73       86       90
# 997    89       87       94
# 998    83       82       78
# 999    66       66       72

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Math     1000 non-null   int64
#  1   Reading  1000 non-null   int64
#  2   Writing  1000 non-null   int64
# dtypes: int64(3)
# memory usage: 23.6 KB

# %%
df.describe()
# Out:
#               Math      Reading      Writing
# count  1000.000000  1000.000000  1000.000000
# mean     67.290000    69.872000    68.616000
# std      15.085008    14.657027    15.241287
# min      13.000000    19.000000    14.000000
# 25%      58.000000    60.750000    58.000000
# 50%      68.000000    70.000000    69.500000
# 75%      78.000000    81.000000    79.000000
# max     100.000000   100.000000   100.000000

# %%
x=df.drop(columns=['Writing']).values
y=df['Writing'].values

# %%
def train_test_split(X, Y, test_size = 0.2, random_state = 42):
    np.random.seed(random_state)
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)

    test_split_size = int(len(X) * test_size)
    training_set = indices[:test_split_size]
    test_set = indices[test_split_size:]
    X_train, X_test = X[training_set], X[test_set]
    Y_train, Y_test = Y[training_set], Y[test_set]
    return X_train, X_test, Y_train, Y_test

# %%
def cost_function(X,Y,W):
  """ Parameters:
This function finds the Mean Square Error.
Input parameters:
X: Feature Matrix
Y: Target Matrix
W: Weight Matrix
Output Parameters:
cost: accumulated mean square error.
"""
  xw=np.dot(X, W)
  n=len(Y)
  cost=(np.sum((xw-Y)**2))/2*n
  return cost

# %%
#Test case
X_test = np.array([[1, 2], [3, 4], [5, 6]])
Y_test = np.array([3, 7, 11])
W_test = np.array([1, 1])
cost = cost_function(X_test, Y_test, W_test)
if cost == 0:
    print("Proceed Further")
else:
    print("something went wrong: Reimplement a cost function")
print("Cost function output:", cost_function(X_test, Y_test, W_test))
# Out:
# Proceed Further
# Cost function output: 0.0

# %%
def gradient_descent(X,Y, W, alpha, iteration):
   """
    Perform gradient descent to optimize the parameters of a linear regression model.
    Parameters:
    X (numpy.ndarray): Feature matrix (m x n).
    Y (numpy.ndarray): Target vector (m x 1).
    W (numpy.ndarray): Initial guess for parameters (n x 1).
    alpha (float): Learning rate.
    iterations (int): Number of iterations for gradient descent.
    Returns:
    tuple: A tuple containing the final optimized parameters (W_update) and the history of cost values
    .
    W_update (numpy.ndarray): Updated parameters (n x 1).
    cost_history (list): History of cost values over iterations.
    """
    #initialize cost history
   cost_history=[0]*iterations
   m=len(Y)
   for iteration in range(iterations):
    #Hypothesis Values
      Y_pred=X.dot(W)

      #Difference between Hypothesis and Actual Y
      loss=Y_pred-Y

      #Gradient Calculation
      dw=(1/m)*np.dot(np.transpose(loss),X)

      #Updating Values of W using Gradient
      W=W-alpha*dw.transpose()

      # New Cost Value
      cost_history[iteration]=cost_function(X,Y,W)

   return W,cost_history

# %%
#Generate random test data
np.random.seed(0)
X=np.random.rand(100,3)
Y=np.random.rand(100)
W=np.random.rand(3) #initial guess for parametres

#set hyperparameters
alpha=0.1
iterations=100
final_params, cost_history = gradient_descent(X, Y, W, alpha, iterations)
print("Final Parameters:",final_params)
print("Cost History: ",cost_history)
# Out:
# Final Parameters: [0.20552222 0.54240883 0.1043444 ]
# Cost History:  [1004.1927167559752, 941.3802300771453, 888.5161518616661, 843.9874762431742, 806.4434083311992, 774.7527267778204, 747.968079726881, 725.296086686571, 706.072302205964, 689.7402507623771, 675.8338708273172, 663.9628137339668, 653.8001331181873, 645.071976194631, 637.5489513435452, 631.0388994184246, 625.3808405113685, 620.4399050315988, 616.1030890352224, 612.2756997724867, 608.8783792144452, 605.8446115723269, 603.1186361063832, 600.6536993191644, 598.4105913452007, 596.3564203233599, 594.4635860531132, 592.7089205288603, 591.0729682160801, 589.5393833457834, 588.0944251988706, 586.726535446273, 585.4259842018431, 584.1845736147042, 582.9953896446989, 581.8525941860253, 580.7512509782147, 579.6871798104744, 578.6568344188086, 577.6572002234404, 576.685708680518, 575.7401655466737, 574.8186907942923, 573.9196682831894, 573.0417036024353, 572.183588754009, 571.3442725659518, 570.5228359035784, 569.7184708987523, 568.9304635440736, 568.1581791050297, 567.4010498920961, 566.6585650092543, 565.9302617577476, 565.2157184261331, 564.514548241404, 563.826394292587, 563.1509252688787, 562.4878318800666, 561.83682384848, 561.1976273797274, 560.5699830345474, 559.953643936737, 559.3483742626838, 558.7539479668903, 558.1701477052897, 557.5967639243601, 557.0335940892479, 556.4804420284576, 555.9371173763177, 555.4034350974832, 554.8792150802881, 554.3642817879103, 553.858463958094, 553.3615943436878, 552.8735094874999, 552.3940495260389, 551.9230580175811, 551.4603817907448, 551.0058708103755, 550.5593780580565, 550.1207594249995, 549.6898736154287, 549.2665820588783, 548.8507488300761, 548.4422405753047, 548.0409264442991, 547.6466780269039, 547.259369293827, 546.8788765409372, 546.5050783366397, 546.1378554719383, 545.7770909128523, 545.4226697549111, 545.074479179492, 544.7324084117993, 544.3963486803201, 544.0661931776116, 543.7418370222996, 543.4231772221867]

# %%
def rmse(Y, Y_pred):
  """
    This Function calculates the Root Mean Squres.
    Input Arguments:
    Y: Array of actual(Target) Dependent Varaibles.
    Y_pred: Array of predeicted Dependent Varaibles.
    Output Arguments:
    rmse: Root Mean Square.
    """
  rmse=np.sqrt(np.sum((Y-Y_pred)**2)/len(Y))
  return rmse

# %%
def r2(Y, Y_pred):
    """
    This Function calculates the R Squared Error.
    Input Arguments:
    Y: Array of actual(Target) Dependent Varaibles.
    Y_pred: Array of predeicted Dependent Varaibles.
    Output Arguments:
    rsquared: R Squared Error.
    """
    mean_y = np.mean(Y)
    ss_tot = np.sum((Y - mean_y) ** 2)
    ss_res = np.sum((Y - Y_pred) ** 2)
    r2 = 1 - (ss_res / ss_tot)
    return r2

# %%
def main():
    # Step 1: Load the dataset
    data = pd.read_csv('/content/drive/MyDrive/Datasets/student.csv')

    # Step 2: Split the data into features (X) and target (Y)
    X = data[['Math', 'Reading']].values # Features
    Y = data['Writing'].values # Target

    # Step 3: Split the data into training and test sets (80% train, 20% test)
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

    # Step 4: Initialize weights (W) to zeros, learning rate and number of iterations
    W = np.zeros(X_train.shape[1])

    alpha = 0.0001 # learning rate
    iterations = 1000 # Number of iterations for gradient descent

    # Step 5: Perform Gradient Descent
    W_optimal, cost_history = gradient_descent(X_train, Y_train, W, alpha, iterations)
    # Step 6: Make predictions on the test set
    Y_pred = np.dot(X_test, W_optimal)

    # Step 7: Evaluate the model using RMSE and R-Squared
    model_rmse = rmse(Y_test, Y_pred)
    model_r2 = r2(Y_test, Y_pred)
    # Step 8: Output the results
    print("Final Weights:", W_optimal)
    print("Cost History (First 10 iterations):", cost_history[:10])
    print("RMSE on Test Set:", model_rmse)
    print("R-Squared on Test Set:", model_r2)


# Execute the main function
if __name__ == "__main__":
    main()
# Out:
# Final Weights: [0.3574393  0.64107392]
# Cost History (First 10 iterations): [769845.7039210295, 708543.7111019213, 706301.3468255234, 704113.6704505695, 701944.8682537371, 699794.7562289935, 697663.1732965169, 695549.9597775214, 693454.9573692986, 691378.0091333507]
# RMSE on Test Set: 5.167811179093556
# R-Squared on Test Set: 0.8826021769916919
